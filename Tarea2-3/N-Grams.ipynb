# %% [markdown]
# # **N-Gram Language Models Implementation**
#
# For the 20N and BAC datasets, perform the processing required to build two N-Gram Language Models:

# %%
#I. Read the files and build two large consolidate files that are the union of all the documents in 20N and BAC.

#20Newsgroups

import xml.etree.ElementTree as ET
import re

def get_sentences_BAC(path) -> list:
    """
    Reads the BAC corpus and returns a list of sentences.
    """
    sentences = []
    lines = ""
    try:

        with open(path, encoding="utf8", errors='ignore') as f:
            lines = f.read()
        lines=lines.replace('&', '')
        lines=lines.replace('<', '')
        lines=lines.replace('>', '')
        root = ET.fromstring(lines)
        for node in root.iter('*'):
            if node.tag == 'post':
                sentences_proc = split_sentences(replace_number(normalize(node.text)))
                sentences = sentences+sentences_proc
    except Exception as e:
        print(f"{path} {str(e)}")
        
    return sentences

# %%
def normalize(text) -> str:
    """
    Normalizes a sentence by stem method.
    """
    from gensim.parsing.porter import PorterStemmer 

    p=PorterStemmer()
    sentences = p.stem_sentence(text)
    return sentences

# %%
# loop for all characters

def replace_number(text) -> str:
    """
    Replaces all numeric characters with a NUM.
    """
    sentences = re.sub(r'\d+', 'NUM', text)
    return sentences

# %%
def split_sentences(text) -> list:
    """
    Splits a text into sentences.
    """
    sentences = re.split(r'[.!?]', text)
    sentences = [f"<s>{s.strip()}</s>" for s in sentences if s.strip() != ""]
    return sentences

# %%
def get_senteces_from_path(path)->list:
    import os
    sentences = []
    for filename in sorted(os.listdir(path)):
        if filename.endswith(".xml"):
            sentences = sentences + get_sentences_BAC(path+filename)
    return sentences

# %%
path = 'Datasets/BAC/blogs/'

s = get_senteces_from_path(path)
print (len(s))
# Out:
# Datasets/BAC/blogs/1022086.female.17.Student.Cancer.xml not well-formed (invalid token): line 1060, column 130
# Datasets/BAC/blogs/1032824.female.15.Student.Libra.xml not well-formed (invalid token): line 1150, column 833
# Datasets/BAC/blogs/1046946.female.25.Arts.Virgo.xml not well-formed (invalid token): line 6348, column 267
# Datasets/BAC/blogs/105748.female.26.Student.Scorpio.xml not well-formed (invalid token): line 2509, column 171
# Datasets/BAC/blogs/1063313.female.16.Student.Libra.xml not well-formed (invalid token): line 96, column 1
# Datasets/BAC/blogs/1070540.female.36.Technology.Scorpio.xml not well-formed (invalid token): line 381, column 1193
# Datasets/BAC/blogs/108212.female.27.Student.Taurus.xml not well-formed (invalid token): line 2495, column 171
# Datasets/BAC/blogs/1084668.female.15.Student.Capricorn.xml not well-formed (invalid token): line 1357, column 1015
# Datasets/BAC/blogs/1089670.female.17.Student.Sagittarius.xml not well-formed (invalid token): line 88, column 572
# Datasets/BAC/blogs/1094221.female.23.Education.Leo.xml not well-formed (invalid token): line 116, column 494
# Datasets/BAC/blogs/1103575.female.17.indUnk.Scorpio.xml not well-formed (invalid token): line 1623, column 116
# Datasets/BAC/blogs/1107146.female.16.Student.Libra.xml not well-formed (invalid token): line 879, column 3700
# Datasets/BAC/blogs/1119650.female.23.Student.Cancer.xml not well-formed (invalid token): line 2943, column 2134
# Datasets/BAC/blogs/1157144.female.17.Student.Libra.xml not well-formed (invalid token): line 5612, column 47
# Datasets/BAC/blogs/1169202.male.26.Science.Libra.xml not well-formed (invalid token): line 124, column 43
# Datasets/BAC/blogs/1250730.male.26.indUnk.Cancer.xml not well-formed (invalid token): line 63, column 430
# Datasets/BAC/blogs/1316855.male.25.Arts.Sagittarius.xml not well-formed (invalid token): line 3275, column 0
# Datasets/BAC/blogs/1330888.female.36.indUnk.Pisces.xml not well-formed (invalid token): line 514, column 162
# Datasets/BAC/blogs/1360750.female.35.Arts.Leo.xml not well-formed (invalid token): line 168, column 61
# Datasets/BAC/blogs/1392111.female.34.indUnk.Leo.xml not well-formed (invalid token): line 16, column 61
# Datasets/BAC/blogs/1395900.male.27.indUnk.Taurus.xml not well-formed (invalid token): line 88, column 1566
# Datasets/BAC/blogs/1415200.female.15.Student.Libra.xml not well-formed (invalid token): line 479, column 2198
# Datasets/BAC/blogs/1427070.female.25.indUnk.Gemini.xml not well-formed (invalid token): line 2761, column 236
# Datasets/BAC/blogs/1461990.female.17.indUnk.Libra.xml not well-formed (invalid token): line 483, column 890
# Datasets/BAC/blogs/1512157.female.15.indUnk.Sagittarius.xml not well-formed (invalid token): line 375, column 824
# Datasets/BAC/blogs/1550687.female.24.Communications-Media.Sagittarius.xml not well-formed (invalid token): line 48, column 207
# Datasets/BAC/blogs/1570566.male.16.indUnk.Gemini.xml not well-formed (invalid token): line 368, column 415
# Datasets/BAC/blogs/1583261.female.16.Arts.Gemini.xml not well-formed (invalid token): line 794, column 1143
# Datasets/BAC/blogs/1592012.male.17.indUnk.Aquarius.xml not well-formed (invalid token): line 343, column 832
# Datasets/BAC/blogs/1634856.female.38.BusinessServices.Scorpio.xml not well-formed (invalid token): line 546, column 2528
# Datasets/BAC/blogs/1645698.male.26.Student.Taurus.xml not well-formed (invalid token): line 1037, column 389
# Datasets/BAC/blogs/1652671.male.16.indUnk.Capricorn.xml not well-formed (invalid token): line 28, column 106
# Datasets/BAC/blogs/1674896.female.15.Student.Capricorn.xml not well-formed (invalid token): line 62, column 1149
# Datasets/BAC/blogs/1685295.female.17.Student.Capricorn.xml not well-formed (invalid token): line 1033, column 389
# Datasets/BAC/blogs/1731592.male.33.indUnk.Gemini.xml not well-formed (invalid token): line 426, column 2703
# Datasets/BAC/blogs/1772041.male.14.Student.Sagittarius.xml not well-formed (invalid token): line 1174, column 713
# Datasets/BAC/blogs/1786125.male.46.indUnk.Virgo.xml not well-formed (invalid token): line 179, column 55
# Datasets/BAC/blogs/1798678.female.17.indUnk.Libra.xml not well-formed (invalid token): line 475, column 7114
# Datasets/BAC/blogs/1820362.female.25.indUnk.Cancer.xml not well-formed (invalid token): line 173, column 1617
# Datasets/BAC/blogs/1862467.female.27.indUnk.Cancer.xml not well-formed (invalid token): line 4994, column 1104
# Datasets/BAC/blogs/1944324.male.16.Student.Taurus.xml not well-formed (invalid token): line 2903, column 1037
# Datasets/BAC/blogs/1945977.female.26.Arts.Pisces.xml not well-formed (invalid token): line 637, column 6
# Datasets/BAC/blogs/1951423.female.24.Arts.Scorpio.xml not well-formed (invalid token): line 3572, column 0
# Datasets/BAC/blogs/1956554.male.24.Technology.Pisces.xml not well-formed (invalid token): line 196, column 481
# Datasets/BAC/blogs/1967338.male.16.Student.Pisces.xml not well-formed (invalid token): line 3026, column 1037
# Datasets/BAC/blogs/1969237.male.43.Sports-Recreation.Cancer.xml not well-formed (invalid token): line 7, column 3354
# Datasets/BAC/blogs/1971502.female.25.BusinessServices.Pisces.xml not well-formed (invalid token): line 837, column 20
# Datasets/BAC/blogs/1987953.male.17.Student.Libra.xml not well-formed (invalid token): line 90, column 534
# Datasets/BAC/blogs/1999563.female.14.Student.Virgo.xml not well-formed (invalid token): line 3953, column 1933
# Datasets/BAC/blogs/2017951.male.26.indUnk.Libra.xml not well-formed (invalid token): line 7, column 888
# Datasets/BAC/blogs/2033501.male.17.indUnk.Cancer.xml not well-formed (invalid token): line 3000, column 1037
# Datasets/BAC/blogs/2046767.female.16.indUnk.Aquarius.xml not well-formed (invalid token): line 2847, column 1037
# Datasets/BAC/blogs/2087401.male.16.Student.Pisces.xml not well-formed (invalid token): line 3203, column 1037
# Datasets/BAC/blogs/2094924.male.16.Non-Profit.Cancer.xml not well-formed (invalid token): line 709, column 1721
# Datasets/BAC/blogs/2134154.male.16.Arts.Taurus.xml not well-formed (invalid token): line 2847, column 1037
# Datasets/BAC/blogs/2147592.female.15.Student.Aquarius.xml not well-formed (invalid token): line 387, column 12
# Datasets/BAC/blogs/2151828.male.17.indUnk.Gemini.xml not well-formed (invalid token): line 2356, column 1257
# Datasets/BAC/blogs/2161435.male.16.Student.Virgo.xml not well-formed (invalid token): line 2302, column 1257
# Datasets/BAC/blogs/2163386.male.26.Government.Taurus.xml not well-formed (invalid token): line 3570, column 6
# Datasets/BAC/blogs/216833.male.24.Student.Scorpio.xml not well-formed (invalid token): line 327, column 57
# Datasets/BAC/blogs/2209219.female.27.indUnk.Cancer.xml not well-formed (invalid token): line 837, column 20
# Datasets/BAC/blogs/2227332.female.16.indUnk.Capricorn.xml not well-formed (invalid token): line 1257, column 13
# Datasets/BAC/blogs/2283987.female.23.Communications-Media.Capricorn.xml not well-formed (invalid token): line 3167, column 6
# Datasets/BAC/blogs/2313100.female.16.indUnk.Leo.xml not well-formed (invalid token): line 697, column 41
# Datasets/BAC/blogs/2344347.male.43.Religion.Cancer.xml not well-formed (invalid token): line 580, column 1328
# Datasets/BAC/blogs/2407445.male.16.Student.Taurus.xml not well-formed (invalid token): line 761, column 798
# Datasets/BAC/blogs/2425281.male.14.Student.Capricorn.xml not well-formed (invalid token): line 260, column 558
# Datasets/BAC/blogs/2434993.male.23.Technology.Capricorn.xml not well-formed (invalid token): line 8, column 8650
# Datasets/BAC/blogs/2485940.male.15.indUnk.Pisces.xml not well-formed (invalid token): line 538, column 1864
# Datasets/BAC/blogs/2492342.male.14.Student.Taurus.xml not well-formed (invalid token): line 745, column 152
# Datasets/BAC/blogs/2495854.male.15.Student.Cancer.xml not well-formed (invalid token): line 127, column 11147
# Datasets/BAC/blogs/2504220.female.17.Sports-Recreation.Aries.xml not well-formed (invalid token): line 2940, column 132
# Datasets/BAC/blogs/2509253.female.15.Arts.Sagittarius.xml not well-formed (invalid token): line 47, column 704
# Datasets/BAC/blogs/2518547.male.16.indUnk.Virgo.xml not well-formed (invalid token): line 784, column 1022
# Datasets/BAC/blogs/259145.female.17.Accounting.Taurus.xml not well-formed (invalid token): line 724, column 287
# Datasets/BAC/blogs/2635801.male.17.indUnk.Scorpio.xml not well-formed (invalid token): line 239, column 52
# Datasets/BAC/blogs/2647863.female.15.indUnk.Capricorn.xml not well-formed (invalid token): line 1564, column 3146
# Datasets/BAC/blogs/2649508.male.44.indUnk.Libra.xml not well-formed (invalid token): line 1249, column 224
# Datasets/BAC/blogs/2665102.female.23.Education.Scorpio.xml not well-formed (invalid token): line 319, column 879
# Datasets/BAC/blogs/2667951.female.24.Non-Profit.Taurus.xml not well-formed (invalid token): line 214, column 763
# Datasets/BAC/blogs/2714376.male.16.Student.Aries.xml not well-formed (invalid token): line 197, column 209
# Datasets/BAC/blogs/2753052.female.14.Student.Scorpio.xml not well-formed (invalid token): line 87, column 81
# Datasets/BAC/blogs/2832770.male.23.Internet.Aries.xml not well-formed (invalid token): line 231, column 3537
# Datasets/BAC/blogs/2835472.male.17.Student.Sagittarius.xml not well-formed (invalid token): line 53, column 1023
# Datasets/BAC/blogs/2877883.female.16.Student.Aries.xml not well-formed (invalid token): line 763, column 507
# Datasets/BAC/blogs/2902960.female.33.Arts.Capricorn.xml not well-formed (invalid token): line 1142, column 353
# Datasets/BAC/blogs/2914457.female.23.Sports-Recreation.Cancer.xml not well-formed (invalid token): line 196, column 7
# Datasets/BAC/blogs/2916583.female.17.Student.Gemini.xml not well-formed (invalid token): line 161, column 2509
# Datasets/BAC/blogs/2920069.female.27.indUnk.Pisces.xml not well-formed (invalid token): line 440, column 1784
# Datasets/BAC/blogs/2932214.male.17.indUnk.Gemini.xml not well-formed (invalid token): line 7, column 961
# Datasets/BAC/blogs/2946306.female.27.indUnk.Aries.xml not well-formed (invalid token): line 70, column 787
# Datasets/BAC/blogs/2949184.male.24.indUnk.Pisces.xml not well-formed (invalid token): line 357, column 141
# Datasets/BAC/blogs/2961544.male.33.indUnk.Libra.xml not well-formed (invalid token): line 305, column 157
# Datasets/BAC/blogs/2975848.female.26.Student.Taurus.xml not well-formed (invalid token): line 735, column 7
# Datasets/BAC/blogs/3006822.male.39.Technology.Cancer.xml not well-formed (invalid token): line 124, column 19397
# Datasets/BAC/blogs/3016212.female.35.indUnk.Aries.xml not well-formed (invalid token): line 946, column 19
# Datasets/BAC/blogs/3017098.female.26.Non-Profit.Gemini.xml not well-formed (invalid token): line 7, column 265
# Datasets/BAC/blogs/3032139.female.26.Arts.Taurus.xml not well-formed (invalid token): line 1544, column 256
# Datasets/BAC/blogs/3051503.male.27.Technology.Libra.xml not well-formed (invalid token): line 102, column 82654
# Datasets/BAC/blogs/3061874.male.25.Technology.Pisces.xml not well-formed (invalid token): line 230, column 1327
# Datasets/BAC/blogs/3071102.female.33.Technology.Cancer.xml not well-formed (invalid token): line 106, column 7
# Datasets/BAC/blogs/3076129.female.15.indUnk.Gemini.xml not well-formed (invalid token): line 17, column 312
# Datasets/BAC/blogs/3077147.female.17.indUnk.Pisces.xml not well-formed (invalid token): line 53, column 1181
# Datasets/BAC/blogs/3087742.male.15.indUnk.Capricorn.xml not well-formed (invalid token): line 1225, column 915
# Datasets/BAC/blogs/3091107.male.23.Engineering.Leo.xml not well-formed (invalid token): line 745, column 2718
# Datasets/BAC/blogs/3092975.female.15.Non-Profit.Leo.xml not well-formed (invalid token): line 128, column 1335
# Datasets/BAC/blogs/3093428.female.17.Student.Taurus.xml not well-formed (invalid token): line 343, column 832
# Datasets/BAC/blogs/3096879.male.23.Marketing.Scorpio.xml not well-formed (invalid token): line 87, column 6881
# Datasets/BAC/blogs/3112880.male.13.Student.Libra.xml not well-formed (invalid token): line 16, column 296
# Datasets/BAC/blogs/3128727.male.23.indUnk.Scorpio.xml not well-formed (invalid token): line 403, column 884
# Datasets/BAC/blogs/3139191.male.16.indUnk.Aquarius.xml not well-formed (invalid token): line 114, column 38
# Datasets/BAC/blogs/3158527.female.15.indUnk.Taurus.xml not well-formed (invalid token): line 134, column 307
# Datasets/BAC/blogs/3169212.female.15.Student.Cancer.xml not well-formed (invalid token): line 691, column 915
# Datasets/BAC/blogs/3196262.male.13.indUnk.Virgo.xml not well-formed (invalid token): line 133, column 350
# Datasets/BAC/blogs/3198682.male.23.indUnk.Sagittarius.xml not well-formed (invalid token): line 147, column 16
# Datasets/BAC/blogs/3208138.male.13.indUnk.Pisces.xml not well-formed (invalid token): line 1654, column 186
# Datasets/BAC/blogs/3211137.male.16.indUnk.Sagittarius.xml not well-formed (invalid token): line 2847, column 1037
# Datasets/BAC/blogs/3238331.male.17.indUnk.Cancer.xml not well-formed (invalid token): line 631, column 397
# Datasets/BAC/blogs/3289321.female.16.Student.Sagittarius.xml not well-formed (invalid token): line 8, column 941
# Datasets/BAC/blogs/3293712.male.16.Student.Taurus.xml not well-formed (invalid token): line 448, column 288
# Datasets/BAC/blogs/3294718.male.16.Student.Capricorn.xml not well-formed (invalid token): line 448, column 288
# Datasets/BAC/blogs/3303349.female.15.Student.Gemini.xml not well-formed (invalid token): line 257, column 6
# Datasets/BAC/blogs/3312717.male.16.Student.Virgo.xml not well-formed (invalid token): line 448, column 288
# Datasets/BAC/blogs/3318771.male.17.Student.Aries.xml not well-formed (invalid token): line 25, column 437
# Datasets/BAC/blogs/3320022.male.26.Telecommunications.Gemini.xml not well-formed (invalid token): line 34, column 1083
# Datasets/BAC/blogs/3321866.male.15.Student.Sagittarius.xml not well-formed (invalid token): line 143, column 88
# Datasets/BAC/blogs/3329253.female.16.Student.Virgo.xml not well-formed (invalid token): line 71, column 72
# Datasets/BAC/blogs/3332146.male.35.Arts.Leo.xml not well-formed (invalid token): line 25, column 734
# Datasets/BAC/blogs/3334323.female.46.indUnk.Leo.xml not well-formed (invalid token): line 700, column 304
# Datasets/BAC/blogs/3335544.male.24.Construction.Gemini.xml not well-formed (invalid token): line 367, column 923
# Datasets/BAC/blogs/3336876.female.37.Non-Profit.Scorpio.xml not well-formed (invalid token): line 481, column 23
# Datasets/BAC/blogs/3342873.male.15.Student.Aquarius.xml not well-formed (invalid token): line 173, column 3183
# Datasets/BAC/blogs/3344979.male.36.Communications-Media.Aries.xml not well-formed (invalid token): line 432, column 139
# Datasets/BAC/blogs/3348466.female.16.LawEnforcement-Security.Taurus.xml not well-formed (invalid token): line 8, column 1933
# Datasets/BAC/blogs/3350141.female.17.Student.Leo.xml not well-formed (invalid token): line 169, column 3187
# Datasets/BAC/blogs/3371144.male.16.indUnk.Sagittarius.xml not well-formed (invalid token): line 448, column 288
# Datasets/BAC/blogs/3374243.male.16.indUnk.Virgo.xml not well-formed (invalid token): line 7, column 8003
# Datasets/BAC/blogs/3378480.male.26.indUnk.Gemini.xml not well-formed (invalid token): line 142, column 340
# Datasets/BAC/blogs/3381418.male.16.indUnk.Sagittarius.xml not well-formed (invalid token): line 31, column 362
# Datasets/BAC/blogs/3385427.male.24.Technology.Capricorn.xml not well-formed (invalid token): line 143, column 3183
# Datasets/BAC/blogs/3401811.female.15.Arts.Capricorn.xml not well-formed (invalid token): line 47, column 1699
# Datasets/BAC/blogs/3402598.female.14.indUnk.Taurus.xml not well-formed (invalid token): line 468, column 397
# Datasets/BAC/blogs/3405975.female.14.Student.Pisces.xml not well-formed (invalid token): line 241, column 74
# Datasets/BAC/blogs/3411004.male.23.Internet.Virgo.xml not well-formed (invalid token): line 178, column 916
# Datasets/BAC/blogs/3415280.male.14.indUnk.Gemini.xml not well-formed (invalid token): line 153, column 667
# Datasets/BAC/blogs/3427781.female.15.Student.Scorpio.xml not well-formed (invalid token): line 115, column 262
# Datasets/BAC/blogs/3432826.male.14.indUnk.Capricorn.xml not well-formed (invalid token): line 52, column 5808
# Datasets/BAC/blogs/3434442.female.14.Student.Scorpio.xml not well-formed (invalid token): line 107, column 625
# Datasets/BAC/blogs/3447712.female.13.Student.Scorpio.xml not well-formed (invalid token): line 37, column 0
# Datasets/BAC/blogs/3452960.female.17.Student.Cancer.xml not well-formed (invalid token): line 2266, column 1257
# Datasets/BAC/blogs/3462927.female.33.Arts.Scorpio.xml not well-formed (invalid token): line 184, column 1736
# Datasets/BAC/blogs/3465792.female.15.Student.Sagittarius.xml not well-formed (invalid token): line 162, column 493
# Datasets/BAC/blogs/3477296.male.15.Student.Virgo.xml not well-formed (invalid token): line 316, column 558
# Datasets/BAC/blogs/3486137.female.14.Military.Aries.xml not well-formed (invalid token): line 8, column 1087
# Datasets/BAC/blogs/3486607.female.16.Student.Sagittarius.xml not well-formed (invalid token): line 246, column 168
# Datasets/BAC/blogs/3486663.female.13.Student.Taurus.xml not well-formed (invalid token): line 103, column 388
# Datasets/BAC/blogs/3486834.female.16.Student.Aries.xml not well-formed (invalid token): line 413, column 999
# Datasets/BAC/blogs/3487346.male.25.Technology.Leo.xml not well-formed (invalid token): line 19, column 2545
# Datasets/BAC/blogs/3490377.male.16.Military.Virgo.xml not well-formed (invalid token): line 341, column 832
# Datasets/BAC/blogs/3494040.male.46.indUnk.Aquarius.xml not well-formed (invalid token): line 52, column 1658
# Datasets/BAC/blogs/3494384.male.17.Student.Scorpio.xml not well-formed (invalid token): line 470, column 1219
# Datasets/BAC/blogs/3497026.female.17.Student.Aries.xml not well-formed (invalid token): line 150, column 147
# Datasets/BAC/blogs/3500830.male.15.indUnk.Pisces.xml not well-formed (invalid token): line 143, column 1213
# Datasets/BAC/blogs/3501335.male.16.indUnk.Aquarius.xml not well-formed (invalid token): line 347, column 877
# Datasets/BAC/blogs/3506494.female.14.Student.Sagittarius.xml not well-formed (invalid token): line 26, column 4367
# Datasets/BAC/blogs/3507581.male.37.indUnk.Virgo.xml not well-formed (invalid token): line 16, column 1122
# Datasets/BAC/blogs/3515542.male.16.indUnk.Pisces.xml not well-formed (invalid token): line 232, column 340
# Datasets/BAC/blogs/3524984.female.16.Student.Aries.xml not well-formed (invalid token): line 116, column 2595
# Datasets/BAC/blogs/3531077.female.16.indUnk.Sagittarius.xml not well-formed (invalid token): line 370, column 766
# Datasets/BAC/blogs/3531623.female.24.indUnk.Capricorn.xml not well-formed (invalid token): line 301, column 239
# Datasets/BAC/blogs/3533261.female.13.Education.Aquarius.xml not well-formed (invalid token): line 63, column 951
# Datasets/BAC/blogs/3540018.female.15.indUnk.Cancer.xml not well-formed (invalid token): line 107, column 1636
# Datasets/BAC/blogs/3547867.female.24.Technology.Capricorn.xml not well-formed (invalid token): line 85, column 682
# Datasets/BAC/blogs/3548434.male.15.indUnk.Pisces.xml not well-formed (invalid token): line 272, column 558
# Datasets/BAC/blogs/3548969.male.35.Advertising.Cancer.xml not well-formed (invalid token): line 7, column 698
# Datasets/BAC/blogs/3550273.male.15.indUnk.Scorpio.xml not well-formed (invalid token): line 260, column 558
# Datasets/BAC/blogs/3554150.male.23.indUnk.Libra.xml not well-formed (invalid token): line 17, column 724
# Datasets/BAC/blogs/3556897.female.25.indUnk.Cancer.xml not well-formed (invalid token): line 41, column 90
# Datasets/BAC/blogs/3567183.female.15.indUnk.Virgo.xml not well-formed (invalid token): line 109, column 396
# Datasets/BAC/blogs/3571449.female.16.indUnk.Aries.xml not well-formed (invalid token): line 76, column 650
# Datasets/BAC/blogs/3574911.male.15.indUnk.Virgo.xml not well-formed (invalid token): line 260, column 558
# Datasets/BAC/blogs/3579464.female.16.Student.Leo.xml not well-formed (invalid token): line 8, column 594
# Datasets/BAC/blogs/3581900.female.17.Student.Aries.xml not well-formed (invalid token): line 47, column 168
# Datasets/BAC/blogs/3582079.male.16.Student.Sagittarius.xml not well-formed (invalid token): line 84, column 168
# Datasets/BAC/blogs/3592450.female.13.indUnk.Aquarius.xml not well-formed (invalid token): line 34, column 616
# Datasets/BAC/blogs/3601348.male.26.indUnk.Sagittarius.xml not well-formed (invalid token): line 196, column 275
# Datasets/BAC/blogs/3607908.male.15.RealEstate.Libra.xml not well-formed (invalid token): line 303, column 434
# Datasets/BAC/blogs/3612838.female.16.Student.Sagittarius.xml not well-formed (invalid token): line 88, column 802
# Datasets/BAC/blogs/3614248.female.14.indUnk.Cancer.xml not well-formed (invalid token): line 23, column 1207
# Datasets/BAC/blogs/3617206.female.26.indUnk.Taurus.xml not well-formed (invalid token): line 384, column 1406
# Datasets/BAC/blogs/3620187.male.16.Student.Libra.xml not well-formed (invalid token): line 85, column 1682
# Datasets/BAC/blogs/3623260.female.14.indUnk.Virgo.xml not well-formed (invalid token): line 52, column 4211
# Datasets/BAC/blogs/3625553.male.27.Internet.Libra.xml not well-formed (invalid token): line 55, column 23
# Datasets/BAC/blogs/3628088.female.17.indUnk.Leo.xml not well-formed (invalid token): line 241, column 2311
# Datasets/BAC/blogs/3628466.female.13.Student.Sagittarius.xml not well-formed (invalid token): line 39, column 473
# Datasets/BAC/blogs/3630293.female.33.Communications-Media.Scorpio.xml not well-formed (invalid token): line 692, column 127
# Datasets/BAC/blogs/3632178.male.15.Student.Capricorn.xml not well-formed (invalid token): line 15, column 1342
# Datasets/BAC/blogs/3633240.female.16.Student.Aries.xml not well-formed (invalid token): line 26, column 21
# Datasets/BAC/blogs/3635006.male.16.indUnk.Taurus.xml not well-formed (invalid token): line 319, column 879
# Datasets/BAC/blogs/3646845.male.16.indUnk.Cancer.xml not well-formed (invalid token): line 31, column 762
# Datasets/BAC/blogs/3647961.male.15.Communications-Media.Gemini.xml not well-formed (invalid token): line 135, column 389
# Datasets/BAC/blogs/3649439.female.15.Arts.Taurus.xml not well-formed (invalid token): line 104, column 355
# Datasets/BAC/blogs/3650031.female.15.Arts.Sagittarius.xml not well-formed (invalid token): line 95, column 355
# Datasets/BAC/blogs/3657693.female.15.Student.Scorpio.xml not well-formed (invalid token): line 8, column 1112
# Datasets/BAC/blogs/3657741.female.23.indUnk.Cancer.xml not well-formed (invalid token): line 790, column 96
# Datasets/BAC/blogs/3667467.male.24.Student.Taurus.xml not well-formed (invalid token): line 1911, column 246
# Datasets/BAC/blogs/3671112.male.17.Student.Leo.xml not well-formed (invalid token): line 47, column 1022
# Datasets/BAC/blogs/3694954.male.25.indUnk.Capricorn.xml not well-formed (invalid token): line 115, column 954
# Datasets/BAC/blogs/3698036.female.15.Education.Libra.xml not well-formed (invalid token): line 7, column 724
# Datasets/BAC/blogs/3699232.male.17.indUnk.Leo.xml not well-formed (invalid token): line 31, column 1561
# Datasets/BAC/blogs/3699514.male.34.InvestmentBanking.Capricorn.xml not well-formed (invalid token): line 178, column 358
# Datasets/BAC/blogs/3703248.male.24.Technology.Virgo.xml not well-formed (invalid token): line 63, column 322
# Datasets/BAC/blogs/3706551.female.41.Technology.Virgo.xml not well-formed (invalid token): line 26, column 24
# Datasets/BAC/blogs/3713583.female.16.indUnk.Aquarius.xml not well-formed (invalid token): line 53, column 1685
# Datasets/BAC/blogs/3720675.female.14.Education.Scorpio.xml not well-formed (invalid token): line 15, column 2009
# Datasets/BAC/blogs/3729488.female.23.indUnk.Taurus.xml not well-formed (invalid token): line 590, column 4898
# Datasets/BAC/blogs/3733539.male.15.indUnk.Taurus.xml not well-formed (invalid token): line 23, column 701
# Datasets/BAC/blogs/3735877.female.15.indUnk.Aquarius.xml not well-formed (invalid token): line 17, column 1459
# Datasets/BAC/blogs/3741677.male.15.indUnk.Gemini.xml not well-formed (invalid token): line 23, column 79
# Datasets/BAC/blogs/3753446.female.23.Student.Capricorn.xml not well-formed (invalid token): line 161, column 432
# Datasets/BAC/blogs/3755327.male.40.indUnk.Pisces.xml not well-formed (invalid token): line 158, column 456
# Datasets/BAC/blogs/3759312.male.24.Arts.Cancer.xml not well-formed (invalid token): line 7, column 374
# Datasets/BAC/blogs/3760594.female.13.indUnk.Capricorn.xml not well-formed (invalid token): line 80, column 774
# Datasets/BAC/blogs/3760622.male.27.Science.Taurus.xml not well-formed (invalid token): line 34, column 800
# Datasets/BAC/blogs/3766618.female.24.indUnk.Aries.xml not well-formed (invalid token): line 10, column 0
# Datasets/BAC/blogs/3776060.male.16.Student.Capricorn.xml not well-formed (invalid token): line 127, column 11
# Datasets/BAC/blogs/3783033.female.15.Education.Pisces.xml not well-formed (invalid token): line 34, column 2131
# Datasets/BAC/blogs/3783158.female.14.indUnk.Scorpio.xml not well-formed (invalid token): line 8, column 1400
# Datasets/BAC/blogs/3785626.female.15.Student.Taurus.xml not well-formed (invalid token): line 8, column 417
# Datasets/BAC/blogs/3787321.male.17.Student.Capricorn.xml not well-formed (invalid token): line 70, column 630
# Datasets/BAC/blogs/3808793.female.13.Student.Taurus.xml not well-formed (invalid token): line 55, column 1147
# Datasets/BAC/blogs/3809161.female.14.indUnk.Leo.xml not well-formed (invalid token): line 15, column 835
# Datasets/BAC/blogs/3813297.female.13.Student.Capricorn.xml not well-formed (invalid token): line 35, column 372
# Datasets/BAC/blogs/3816334.female.23.Student.Leo.xml not well-formed (invalid token): line 59, column 900
# Datasets/BAC/blogs/3818445.female.15.Student.Taurus.xml not well-formed (invalid token): line 61, column 2811
# Datasets/BAC/blogs/3818898.male.24.Consulting.Leo.xml not well-formed (invalid token): line 7, column 6599
# Datasets/BAC/blogs/3824121.female.15.Student.Virgo.xml not well-formed (invalid token): line 95, column 694
# Datasets/BAC/blogs/3824541.male.15.Student.Pisces.xml not well-formed (invalid token): line 395, column 120
# Datasets/BAC/blogs/3824610.male.16.indUnk.Aries.xml not well-formed (invalid token): line 7, column 76
# Datasets/BAC/blogs/3825729.female.16.Student.Aquarius.xml not well-formed (invalid token): line 24, column 567
# Datasets/BAC/blogs/3827100.female.16.Student.Scorpio.xml not well-formed (invalid token): line 312, column 383
# Datasets/BAC/blogs/3838581.female.15.indUnk.Cancer.xml not well-formed (invalid token): line 35, column 3986
# Datasets/BAC/blogs/3838711.male.15.Student.Scorpio.xml not well-formed (invalid token): line 179, column 4077
# Datasets/BAC/blogs/3842054.male.15.Student.Aries.xml not well-formed (invalid token): line 503, column 1047
# Datasets/BAC/blogs/3842760.female.14.Student.Pisces.xml not well-formed (invalid token): line 17, column 317
# Datasets/BAC/blogs/3843378.male.27.Arts.Gemini.xml not well-formed (invalid token): line 8, column 2271
# Datasets/BAC/blogs/3849574.female.23.Internet.Taurus.xml not well-formed (invalid token): line 19, column 366
# Datasets/BAC/blogs/3854685.female.14.indUnk.Gemini.xml not well-formed (invalid token): line 38, column 1001
# Datasets/BAC/blogs/3858875.female.25.Student.Libra.xml not well-formed (invalid token): line 26, column 856
# Datasets/BAC/blogs/3865939.female.15.indUnk.Pisces.xml not well-formed (invalid token): line 27, column 1726
# Datasets/BAC/blogs/3882131.female.13.indUnk.Aries.xml not well-formed (invalid token): line 87, column 2276
# Datasets/BAC/blogs/3882397.male.34.Transportation.Leo.xml not well-formed (invalid token): line 500, column 1010
# Datasets/BAC/blogs/3884025.female.14.Arts.Capricorn.xml not well-formed (invalid token): line 47, column 1381
# Datasets/BAC/blogs/3886279.female.25.Arts.Libra.xml not well-formed (invalid token): line 34, column 6624
# Datasets/BAC/blogs/3891408.female.16.indUnk.Libra.xml not well-formed (invalid token): line 17, column 1693
# Datasets/BAC/blogs/3897244.male.17.Student.Aries.xml not well-formed (invalid token): line 119, column 213
# Datasets/BAC/blogs/3898365.male.16.Student.Sagittarius.xml not well-formed (invalid token): line 160, column 2435
# Datasets/BAC/blogs/3906531.male.15.Education.Gemini.xml not well-formed (invalid token): line 86, column 4366
# Datasets/BAC/blogs/3909310.female.15.Student.Virgo.xml not well-formed (invalid token): line 39, column 1838
# Datasets/BAC/blogs/3909578.female.16.indUnk.Aquarius.xml not well-formed (invalid token): line 43, column 340
# Datasets/BAC/blogs/3910716.female.16.Student.Libra.xml not well-formed (invalid token): line 198, column 3147
# Datasets/BAC/blogs/3912191.female.15.Student.Aries.xml not well-formed (invalid token): line 7, column 1373
# Datasets/BAC/blogs/3912595.female.17.indUnk.Taurus.xml not well-formed (invalid token): line 17, column 73
# Datasets/BAC/blogs/3926076.female.17.Student.Cancer.xml not well-formed (invalid token): line 89, column 236
# Datasets/BAC/blogs/3934964.male.23.Publishing.Virgo.xml not well-formed (invalid token): line 7, column 750
# Datasets/BAC/blogs/3938722.male.14.Student.Taurus.xml not well-formed (invalid token): line 55, column 2178
# Datasets/BAC/blogs/3948250.male.26.Internet.Aries.xml not well-formed (invalid token): line 9, column 159
# Datasets/BAC/blogs/3956394.female.13.Student.Scorpio.xml not well-formed (invalid token): line 148, column 1194
# Datasets/BAC/blogs/3957678.female.16.indUnk.Gemini.xml not well-formed (invalid token): line 15, column 43
# Datasets/BAC/blogs/3980716.male.16.indUnk.Virgo.xml not well-formed (invalid token): line 98, column 3042
# Datasets/BAC/blogs/3983759.female.15.indUnk.Virgo.xml not well-formed (invalid token): line 14, column 458
# Datasets/BAC/blogs/3986070.female.15.Education.Aries.xml not well-formed (invalid token): line 32, column 9
# Datasets/BAC/blogs/3996270.male.14.Education.Scorpio.xml not well-formed (invalid token): line 23, column 7004
# Datasets/BAC/blogs/3998954.male.23.Consulting.Capricorn.xml not well-formed (invalid token): line 284, column 201
# Datasets/BAC/blogs/4000416.male.26.Science.Scorpio.xml not well-formed (invalid token): line 236, column 29
# Datasets/BAC/blogs/4003282.female.17.Student.Aquarius.xml not well-formed (invalid token): line 41, column 173
# Datasets/BAC/blogs/4006686.male.24.Engineering.Gemini.xml not well-formed (invalid token): line 145, column 128
# Datasets/BAC/blogs/4011284.female.16.indUnk.Libra.xml not well-formed (invalid token): line 31, column 237
# Datasets/BAC/blogs/4011411.female.16.Student.Libra.xml not well-formed (invalid token): line 97, column 221
# Datasets/BAC/blogs/4020412.female.13.indUnk.Gemini.xml not well-formed (invalid token): line 47, column 600
# Datasets/BAC/blogs/4021850.female.17.indUnk.Taurus.xml not well-formed (invalid token): line 1164, column 68
# Datasets/BAC/blogs/4021913.female.14.indUnk.Libra.xml not well-formed (invalid token): line 17, column 29
# Datasets/BAC/blogs/4025480.female.15.Student.Leo.xml not well-formed (invalid token): line 47, column 329
# Datasets/BAC/blogs/4027704.female.17.indUnk.Aquarius.xml not well-formed (invalid token): line 53, column 2095
# Datasets/BAC/blogs/4029742.female.14.indUnk.Aries.xml not well-formed (invalid token): line 94, column 198
# Datasets/BAC/blogs/4037965.female.17.Science.Aquarius.xml not well-formed (invalid token): line 97, column 221
# Datasets/BAC/blogs/4046669.male.25.indUnk.Libra.xml not well-formed (invalid token): line 382, column 994
# Datasets/BAC/blogs/4052167.female.35.Education.Libra.xml not well-formed (invalid token): line 16, column 61
# Datasets/BAC/blogs/4066337.male.25.Communications-Media.Leo.xml not well-formed (invalid token): line 178, column 47
# Datasets/BAC/blogs/4069578.male.15.indUnk.Aquarius.xml not well-formed (invalid token): line 81, column 469
# Datasets/BAC/blogs/4075024.female.13.Student.Pisces.xml not well-formed (invalid token): line 183, column 619
# Datasets/BAC/blogs/4081161.female.17.Student.Cancer.xml not well-formed (invalid token): line 74, column 3007
# Datasets/BAC/blogs/4081607.male.17.Student.Virgo.xml not well-formed (invalid token): line 7, column 337
# Datasets/BAC/blogs/4088003.female.17.indUnk.Gemini.xml not well-formed (invalid token): line 126, column 697
# Datasets/BAC/blogs/4091758.male.16.indUnk.Taurus.xml not well-formed (invalid token): line 39, column 869
# Datasets/BAC/blogs/4100189.male.17.indUnk.Taurus.xml not well-formed (invalid token): line 7, column 494
# Datasets/BAC/blogs/4110895.male.14.Student.Gemini.xml not well-formed (invalid token): line 8, column 345
# Datasets/BAC/blogs/4112653.female.15.Student.Sagittarius.xml not well-formed (invalid token): line 353, column 88
# Datasets/BAC/blogs/4113328.male.14.indUnk.Capricorn.xml not well-formed (invalid token): line 134, column 88
# Datasets/BAC/blogs/4115881.male.24.Technology.Cancer.xml not well-formed (invalid token): line 25, column 234
# Datasets/BAC/blogs/4118729.female.16.Fashion.Scorpio.xml not well-formed (invalid token): line 67, column 2331
# Datasets/BAC/blogs/4119314.female.14.indUnk.Capricorn.xml not well-formed (invalid token): line 75, column 272
# Datasets/BAC/blogs/4122384.male.15.indUnk.Gemini.xml not well-formed (invalid token): line 98, column 88
# Datasets/BAC/blogs/4126520.female.15.indUnk.Capricorn.xml not well-formed (invalid token): line 62, column 748
# Datasets/BAC/blogs/4134395.male.27.indUnk.Aquarius.xml not well-formed (invalid token): line 79, column 545
# Datasets/BAC/blogs/4138278.female.17.LawEnforcement-Security.Virgo.xml not well-formed (invalid token): line 7, column 3098
# Datasets/BAC/blogs/4145578.male.15.indUnk.Libra.xml not well-formed (invalid token): line 43, column 1822
# Datasets/BAC/blogs/4151409.male.25.Engineering.Cancer.xml not well-formed (invalid token): line 98, column 65
# Datasets/BAC/blogs/4153600.female.16.Student.Gemini.xml not well-formed (invalid token): line 39, column 38
# Datasets/BAC/blogs/4155194.female.15.indUnk.Taurus.xml not well-formed (invalid token): line 8, column 887
# Datasets/BAC/blogs/4159332.female.15.indUnk.Capricorn.xml not well-formed (invalid token): line 27, column 899
# Datasets/BAC/blogs/4160528.female.16.Student.Leo.xml not well-formed (invalid token): line 72, column 9335
# Datasets/BAC/blogs/416465.male.24.indUnk.Pisces.xml not well-formed (invalid token): line 53, column 41
# Datasets/BAC/blogs/4177529.male.16.Student.Aries.xml not well-formed (invalid token): line 107, column 9
# Datasets/BAC/blogs/4180104.male.16.indUnk.Scorpio.xml not well-formed (invalid token): line 7, column 454
# Datasets/BAC/blogs/4182405.male.23.Government.Capricorn.xml not well-formed (invalid token): line 23, column 56
# Datasets/BAC/blogs/4197491.male.16.Education.Scorpio.xml not well-formed (invalid token): line 107, column 1388
# Datasets/BAC/blogs/4199639.female.17.indUnk.Gemini.xml not well-formed (invalid token): line 31, column 2518
# Datasets/BAC/blogs/4201404.male.27.indUnk.Cancer.xml not well-formed (invalid token): line 16, column 12740
# Datasets/BAC/blogs/4211779.female.13.Student.Leo.xml not well-formed (invalid token): line 31, column 136
# Datasets/BAC/blogs/4212494.male.17.Student.Virgo.xml not well-formed (invalid token): line 16, column 166
# Datasets/BAC/blogs/4217949.female.16.indUnk.Cancer.xml not well-formed (invalid token): line 8, column 81
# Datasets/BAC/blogs/4220192.male.24.Military.Leo.xml not well-formed (invalid token): line 15, column 725
# Datasets/BAC/blogs/4225783.male.33.Education.Aries.xml not well-formed (invalid token): line 7, column 3084
# Datasets/BAC/blogs/4230100.female.13.Education.Capricorn.xml not well-formed (invalid token): line 52, column 462
# Datasets/BAC/blogs/4240336.female.17.Student.Scorpio.xml not well-formed (invalid token): line 97, column 146
# Datasets/BAC/blogs/4254048.female.15.Student.Libra.xml not well-formed (invalid token): line 359, column 128
# Datasets/BAC/blogs/4284947.female.16.Student.Gemini.xml not well-formed (invalid token): line 393, column 293
# Datasets/BAC/blogs/4299910.male.17.Student.Cancer.xml not well-formed (invalid token): line 56, column 289
# Datasets/BAC/blogs/4300864.female.26.Religion.Sagittarius.xml not well-formed (invalid token): line 15, column 3559
# Datasets/BAC/blogs/4307329.female.16.Student.Libra.xml not well-formed (invalid token): line 56, column 289
# Datasets/BAC/blogs/4312209.female.16.indUnk.Virgo.xml not well-formed (invalid token): line 7, column 331
# Datasets/BAC/blogs/536510.female.24.RealEstate.Capricorn.xml not well-formed (invalid token): line 727, column 54
# Datasets/BAC/blogs/576311.female.34.indUnk.Capricorn.xml not well-formed (invalid token): line 2715, column 0
# Datasets/BAC/blogs/580228.male.17.Communications-Media.Libra.xml not well-formed (invalid token): line 2254, column 2032
# Datasets/BAC/blogs/619488.female.25.indUnk.Cancer.xml not well-formed (invalid token): line 240, column 174
# Datasets/BAC/blogs/639993.male.39.Government.Aries.xml not well-formed (invalid token): line 567, column 435
# Datasets/BAC/blogs/655250.female.24.indUnk.Cancer.xml not well-formed (invalid token): line 2494, column 171
# Datasets/BAC/blogs/691951.female.15.Biotech.Cancer.xml not well-formed (invalid token): line 8, column 714
# Datasets/BAC/blogs/748386.female.26.Internet.Taurus.xml not well-formed (invalid token): line 80, column 76
# Datasets/BAC/blogs/772682.female.23.Arts.Libra.xml not well-formed (invalid token): line 988, column 316
# Datasets/BAC/blogs/78196.female.35.indUnk.Aries.xml not well-formed (invalid token): line 3257, column 367
# Datasets/BAC/blogs/848630.female.23.indUnk.Cancer.xml not well-formed (invalid token): line 1808, column 63
# Datasets/BAC/blogs/918871.male.17.Automotive.Leo.xml not well-formed (invalid token): line 255, column 100
# Datasets/BAC/blogs/925742.male.16.Student.Gemini.xml not well-formed (invalid token): line 1681, column 23
# Datasets/BAC/blogs/950122.female.15.Student.Virgo.xml not well-formed (invalid token): line 255, column 233
# Datasets/BAC/blogs/958176.male.17.Non-Profit.Gemini.xml not well-formed (invalid token): line 879, column 3700
# Datasets/BAC/blogs/977947.female.17.indUnk.Aries.xml not well-formed (invalid token): line 8, column 2626
# Datasets/BAC/blogs/980975.female.16.indUnk.Pisces.xml not well-formed (invalid token): line 77, column 862
# 10527279

# %%
import tarfile

tar = tarfile.open("datos/20news-19997.tar.gz", "r:gz")
for member in tar.getmembers():
     f = tar.extractfile(member)
     if f is not None:
         content = f.read()

# %%
#read tar gz file
def read_tar_gz(tar_gz_file):
    tar = tarfile.open(tar_gz_file, "r:gz")
    for member in tar.getmembers():
        f = tar.extractfile(member)
        if f is not None:
            content = f.read()
            yield content
            f.close()
            tar.close()
